# %% [markdown]
# # Sample Notebook
#
# This is a small demo notebook for **MudExFileDisplayNotebook**.

# %%
print('Hello from Python!')
# Out:
# Hello from Python!

# %%
sum(range(6))
# Out:
# 15

# %% [markdown]
# ## Errors are rendered too

# %%
1 / 0
# Out:
# Traceback (most recent call last):
# ZeroDivisionError: division by zero
